# %% [markdown]
# # Using ADMM to detect the sneezing panda

# %%
import scipy.io as sio

D = sio.loadmat('/Users/x/work/thesis/notes/features_D-ZBcmcje_s.mat')
mov = D['mov']
mov_bw = D['mov_bw']
cuboids = D['cuboids']
original_hog = D['hog']
original_hof = D['hof']
original_vals = D['vals']
original_locs = D['subs']

sort_order = np.argsort(original_locs[:,2])

locs = original_locs[sort_order, :]
vals = original_vals[sort_order, :]
hogs = original_hog[sort_order, :]
hofs = original_hof[sort_order, :]

# %% [markdown]
# Let's start the dictionary learning process

# %%
import matplotlib.pyplot as plt

plt.imshow(mov_bw[:, :,0], cmap='gray')

# %% [markdown]
# Now, let's do sparse coding on the HOG values. We take the first 20% as training.

# %%
length = hogs.shape[0]
length
# Out:
# 1526

# %%
limit = length * 20 / 100

# %%
training = hofs[:limit]

# %%
training.shape
# Out:
# (305, 198)

# %% [markdown]
# We will use that 180 items array on each of the HOG values as the info to reconstruct.

# %%
import numpy as np

X = training
intercept = np.mean(X, axis=0)
X -= intercept
deviation = np.std(X, axis=0)
X /= deviation
X.shape
# Out:
# (305, 198)

# %%
from admm.lasso import dict_learning

code, dictionary, errors = dict_learning(X, n_components=100,alpha=1)

# %%
dictionary.shape
# Out:
# (100, 198)

# %%
# BTW, that dict_learning call took about 10 minutes on my workstation

# %% [markdown]
# Let's try to sparse_encode the first item and check that it has some zeros :)

# %%
first_frame  = X[0]

# %%
first_frame.shape
# Out:
# (198,)

# %%
from admm.lasso import lasso_admm

first_code, first_errors = lasso_admm(first_frame, dictionary, gamma=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-dd4355d065c0> in <module>()
#       1 from admm.lasso import lasso_admm
#       2
# ----> 3 first_code, first_errors = lasso_admm(first_frame, dictionary, gamma=1)
#
# /Users/x/work/thesis/notes/admm/lasso.pyc in lasso_admm(X, D, gamma, C, double, max_rho, rho, max_iter)
#      40
#      41         if len(item.shape) < 2:
# ---> 42             raise ValueError("Expected a matrix, found an array instead with shape %s" % item.shape)
#      43
#      44     c = X.shape[1]
#
# ValueError: Expected a matrix, found an array instead with shape 198
