# %%
import cv2
import csv
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl
import pandas
import numpy as np
from pandas.io.parsers import read_csv
from admm.dict_learning import MiniBatchDictionaryLearning
from admm.lasso import lasso_cost
from pandas.stats.moments import rolling_apply
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
from IPython.display import display

# %matplotlib inline

def train(d, dico=None, components=200, alpha=1, n_iter=100, method='lars', batch_size=100, fit=True):
    
    if dico is None:
        dico = MiniBatchDictionaryLearning(n_components=components, fit_algorithm=method, transform_algorithm='lasso_'+method, alpha=alpha, n_iter=n_iter, batch_size=batch_size)

    if fit:
        dico.fit(d)

    dictionary = dico.components_
        
    code = dico.transform(d)
    patches = np.dot(code, dictionary)
    error = ((d - patches) ** 2).mean(axis=1)
    
    # Sparsity component is exaggerated (10 instead of 1).
    cost = [lasso_cost(d[x,:], dictionary.T, code[x,:], 10) for x in range(code.shape[0])]
    
    return dictionary, code, error, dico, cost


def draw_groundtruth(y, xstart, xstop, color='b'):
    """Plot timelines at y from xstart to xstop with given color."""   
    plt.hlines(y, xstart, xstop, color, lw=4)
    plt.vlines(xstart, y+ 0.03, y-0.03, color, lw=2)
    plt.vlines(xstop, y+0.03, y-0.03, color, lw=2)
    

def check(input_data, groundtruth, error_limit=0, STEP=8000):

    frames = np.array(range(1, 62000))

    frame_error = input_data[input_data.error > error_limit].get(['frameNum', 'error'])
    # frame error sum
    fes  = frame_error.groupby(by='frameNum').agg(np.sum)


    for index in range(0, len(frames), STEP):
        
        frames_vect = np.array(range(index, index + STEP+1))

        values_vect = np.zeros(frames_vect.shape)

        for frame, error in fes[(fes.index > index) & (fes.index < index+STEP)].itertuples():
            values_vect[frame - index] = error

        plt.figure()
        plt.gcf().set_figwidth(15)

        YLIM = 10

        plt.plot(frames_vect, values_vect, color='green', label='error sum')
        plt.hold()

        for start, end, value in groundtruth:
            color = 'red' if value == 1 else 'black'
            height = YLIM * 0.7 if value == 1 else YLIM * 0.3
            draw_groundtruth(height, start, end, color=color)        
            draw_groundtruth(YLIM - height, start, end, color=color)        

        plt.title("Frames %s to %s" % (index, index+STEP))

        plt.xlim(index, index + STEP)
        plt.ylim((0, YLIM))
        
    return fes

from IPython.display import HTML

def entrance_detection(detection, label="Ours"):
    
    s = """
    <head>
    <style>
    table {
        font-family:Arial, Helvetica, sans-serif;
        color:#666;
        font-size:16px;
        text-shadow: 1px 1px 0px #fff;
        margin:20px;
        border:#ccc 1px solid;
    }
    table th {
        padding:21px 25px 22px 25px;
        border-top:1px solid #fafafa;
        border-bottom:1px solid #e0e0e0;
    
    }
    
    table tr {
        text-align: center;
        padding-left:20px;
    }
    table td:first-child {
        text-align: left;
        padding-left:20px;
        border-left: 0;
    }
    table td {
        padding:18px;
        text-align: center;
        border-top: 1px solid #ffffff;
        border-bottom:1px solid #e0e0e0;
        border-left: 1px solid #e0e0e0;
        width: 20px;
    }
    
    </style>
    </head>
    <body>
        <table>
    <thead>
    <tr>
    <th></th>
    <th>Wrong Direction</th>
    <th>No Payment</th>
    <th>Loitering</th>
    <th>Irregular Interactions</th>
    <th>Miscelaneous</th>
    <th>Total</th>
    <th>False Alarm</th>
    </tr>
    </thead>
    <tr>
    <td>Ground Truth</td>
    <td>26</td>
    <td>13</td>
    <td>14</td>
    <td>4</td>
    <td>9</td>
    <td>66</td>
    <td>0</td>
    </tr>
    <tr>
    <td>Zhao Online</td>
    <td>24</td>
    <td>8</td>
    <td>13</td>
    <td>4</td>
    <td>8</td>
    <td>57</td>
    <td>6</td>
    </tr>
    <tr>
    <td>Zhao Online</td>
    <td>25</td>
    <td>9</td>
    <td>14</td>
    <td>4</td>
    <td>8</td>
    <td>60</td>
    <td>5</td>
    </tr>
    <tr>
    <td>150 FPS</td>
    <td>25</td>
    <td>7</td>
    <td>13</td>
    <td>4</td>
    <td>8</td>
    <td>57</td>
    <td>4</td>
    </tr>
    <tr>
    <td>%(label)s</td>
    <td>%(wrongdir)s</td>
    <td>%(nopay)s</td>
    <td>%(loitering)s</td>
    <td>%(interaction)s</td>
    <td>%(etc)s</td>
    <td>%(total)s</td>
    <td>%(false_alarm)s</td>
    </tr>
    
    </table>
    </body>
    """
    detection['label'] = label
    return HTML(s % detection)


def exit_detection(detection, label="Ours"):
    
    s = """
    <head>
    <style>
    table {
        font-family:Arial, Helvetica, sans-serif;
        color:#666;
        font-size:16px;
        text-shadow: 1px 1px 0px #fff;
        margin:20px;
        border:#ccc 1px solid;
    }
    table th {
        padding:21px 25px 22px 25px;
        border-top:1px solid #fafafa;
        border-bottom:1px solid #e0e0e0;
    
    }
    
    table tr {
        text-align: center;
        padding-left:20px;
    }
    table td:first-child {
        text-align: left;
        padding-left:20px;
        border-left: 0;
    }
    table td {
        padding:18px;
        text-align: center;
        border-top: 1px solid #ffffff;
        border-bottom:1px solid #e0e0e0;
        border-left: 1px solid #e0e0e0;
        width: 20px;
    }
    
    </style>
    </head>
    <body>
        <table>
    <thead>
    <tr>
    <th></th>
    <th>Wrong Direction</th>
    <th>Loitering</th>
    <th>ETC</th>
    <th>Total</th>
    <th>False Alarm</th>
    </tr>
    </thead>
    <tr>
    <td>Ground Truth</td>
    <td>9</td>
    <td>3</td>
    <td>7</td>
    <td>19</td>
    <td>0</td>
    </tr>
    <tr>
    <td>ST-MRF</td>
    <td>9</td>
    <td>3</td>
    <td>7</td>
    <td>19</td>
    <td>3</td>
    </tr>
    <tr>
    <td>Zhao Online</td>
    <td>9</td>
    <td>3</td>
    <td>7</td>
    <td>19</td>
    <td>2</td>
    </tr>
    <tr>
    <td>150 FPS</td>
    <td>9</td>
    <td>3</td>
    <td>7</td>
    <td>19</td>
    <td>2</td>
    </tr>
    <tr>
    <td>%(label)s</td>
    <td>%(wrongdir)s</td>
    <td>%(loitering)s</td>
    <td>%(misc)s</td>
    <td>%(total)s</td>
    <td>%(false_alarm)s</td>
    </tr>
    
    </table>
    </body>
    """
    detection['label'] = label
    return HTML(s % detection)


def draw_trajectories(video_filename, data, groundtruth, output_video_filename, thickness=0):
    '''Draws cuboids.
    video_filename: string
    data: DataFrame with frameNumber, error and trajectory
    
    output_video_file_name: string
    
    edge: width in pixels of cuboid outlines
    outline: draws only cuboid outlines when 0, solid cuboids otherwise
    
    Author: Ariel Nunez, 2014
            Juan Carlos Niebles, 2013
    '''
    
    # Open input video.
    input_video = cv2.VideoCapture(video_filename)
    if not input_video.isOpened():
        print "Cannot open input video", video_filename ,"for reading."
        return None
    frame_width = np.uint32(input_video.get(cv2.cv.CV_CAP_PROP_FRAME_WIDTH))
    frame_height = np.uint32(input_video.get(cv2.cv.CV_CAP_PROP_FRAME_HEIGHT))
    
    # Open output video.
    output_video = cv2.VideoWriter()
    output_video.open(output_video_filename, cv2.cv.CV_FOURCC('F','M', 'P','4'),
                      60, (frame_width, frame_height), 1)
    if not output_video.isOpened():
        output_video.release()
        print "Cannot open output video", output_video_filename ,"for writing."
        return None
    
    # Keep track of current frame number.
    frame_number = -1
    
    min_error = data.error.min()
    max_error = data.error.max()
    
    # Loop through all frames, drawing cuboids at each frame.
    while True:
        retval, frame = input_video.read()
        if (type(frame) == type(None)):
            break
        frame_number += 1
        
        ignore = True
        usual = True
        
        for start, end, value in groundtruth:
            if (frame_number > start) & (frame_number <= end):
                if value == 1:
                    usual = False
                ignore = False
                break
        
        # If this frame is not in the groundtruth, don't draw it.
        if ignore:
            continue

        # When drawing a solid cuboid, we operate on the HSV color space.
        gray_frame = cv2.cvtColor(frame.copy(), cv2.COLOR_BGR2GRAY)
        output_frame = np.zeros((gray_frame.shape[0], gray_frame.shape[1], 3),
                                    dtype=np.uint8)
        output_frame[:, :, 2] = gray_frame
        
        # Add trajectories
        filtered = data[(data.frameNum > frame_number) & (data.frameNum < frame_number + 15)]
                
        for index, row in filtered.iterrows():
            trajectory = np.array(row.trajectory).reshape((15, 2))
            x_last = None
            y_last = None
            
            difference = row.frameNum - frame_number

            for x, y in trajectory:
                max_error, min_error, row.error
                level = (row.error - min_error ) / (max_error - min_error)
                color = np.array([  0.,   (level-0.2)*255., 255., 255.])
                
                if x_last is not None and level > 0.2:
                    cv2.line(output_frame, (int(x_last), int(y_last)), (int(x), int(y)), color, thickness=2, lineType=cv2.CV_AA)                    
                    
                x_last = x
                y_last = y
        
        # Add frame number
        if usual:
            text = '%s' % frame_number
            color = (180, 0, 255)
        else:
            text = '%s (unusual)' % frame_number
            color = (0, 128, 255)
                    
        cv2.putText(output_frame, text, (5, 25),
                    cv2.FONT_HERSHEY_SIMPLEX, 1.0, color)
        
        output_frame = cv2.cvtColor(output_frame, cv2.COLOR_HSV2BGR_FULL)
        output_video.write(output_frame)
        

    print "Done."
    # Close video objects
    input_video.release()
    output_video.release()

    
def get_ground_truth(filename=None, actions=None):
    """Parse ground truth locations from a CSV file
    
       For example:
          get_ground_truth(filename='/home/x/traj/subway-entrance-ground-truth.csv', actions=["nopay", "loitering", "wrongdir","interaction", "etc"])
          get_ground_truth(filename='/home/x/traj/subway-exit-ground-truth.csv', actions=["nopay", "loitering", "wrongdir","misc"])
    """
    csvfile = open(filename, 'r')
    fieldnames = ["clip_info",]
    fieldnames.extend(actions)
    reader = csv.DictReader( csvfile, fieldnames, delimiter=',',)
    data = [ row for row in reader ]
    # Remove the header
    data = data[1:]

    # Get the frame numbers
    clip_numbers = len(data)

    clips = []

    for item in data:
        clip_info = item["clip_info"].strip()
        start, end = clip_info.split(" ")
        found_actions = []
        for key in actions:
            if item[key] != "":
                found_actions.append(key)

        clips.append((int(start), int(end), found_actions))
    
    return clips

    
def unusual_events(trajectory_file=None, groundtruth=None, actions=None, method='lars', error_limit=0, peak_threshold=1, plot=True):
    metadata_fields = ['frameNum', 'mean_x', 'mean_y', 'var_x', 'var_y', 'length', 'scale', 'x_pos', 'y_pos', 't_pos']
    norm_trajectory_fields = ['norm_trajectory%s' % n for n in range(30)]
    trajectory_fields = ['trajectory%s' % n for n in range(30)]
    hog_fields = ['hog%s' % n for n in range(96)]
    hof_fields = ['hof%s' % n for n in range(108)]
    mbh_fields = ['mbh%s' % n for n in range(96+96)]

    fields = metadata_fields + norm_trajectory_fields + trajectory_fields + hog_fields + hof_fields + mbh_fields

    temp_data = read_csv(trajectory_file, delimiter='\t', names=fields, index_col=False)
    data = pandas.concat([
            temp_data.get(metadata_fields),
            pandas.Series(temp_data.get(hof_fields).values.tolist(), index=temp_data.index, name='hof'),
            pandas.Series(temp_data.get(hog_fields).values.tolist(), index=temp_data.index, name='hog'),
            pandas.Series(temp_data.get(mbh_fields).values.tolist(), index=temp_data.index, name='mbh'),
            pandas.Series(temp_data.get(trajectory_fields).values.tolist(), index=temp_data.index, name='trajectory'),
], axis=1)
    
    normal_data = None

    # Create a dataset with only normal events.
    for start, end, normal in groundtruth:

        tmp_data = data[(data.frameNum >= start) & (data.frameNum <= end)]

        # ignore events labeled as abnormal
        if normal == 1:
            break

        normal_data = pandas.concat([normal_data, tmp_data])
        
    mbh = np.array(normal_data.mbh.values.tolist())
    
    mbh_reference = mbh
    intercept = mbh_reference.mean(axis=0)
    delta_reference =  mbh_reference - intercept
    deviation = delta_reference.std(axis=0)

    # Use the intercept and deviation from the initial values:
    delta = mbh - intercept
    d = delta / deviation
    
    dictionary, code, error, dico, cost = train(d, alpha=1, method=method, n_iter=10, batch_size=100, components=50)
    
    normal_data['error'] = pandas.Series(error, index=normal_data.index, name='error')
    normal_data['cost'] = pandas.Series(cost, index=normal_data.index, name='cost')

    
    all_mbh = np.array(data.mbh.values.tolist())
    # Use the intercept and deviation from the initial values:
    delta = all_mbh - intercept
    new_d = delta / deviation

    code = dico.transform(new_d)
    patches = np.dot(code, dictionary)
    new_error = ((new_d - patches) ** 2).mean(axis=1)
    
    cost = [lasso_cost(new_d[x,:], dictionary.T, code[x,:], 1) for x in range(code.shape[0])]
    
    data['error'] = pandas.Series(new_error, index=data.index, name='error')
    data['cost'] = pandas.Series(cost, index=data.index, name='cost')
    
    frame_error = data[data.error > error_limit].get(['frameNum', 'cost', 'error'])
    # frame error sum
    fes  = frame_error.groupby(by='frameNum').agg(np.sum)
    
    mad = lambda x: np.fabs(x - x.mean()).mean()
    moving_window_frames = 10
    smooth_error = rolling_apply(fes, moving_window_frames, mad)
    smooth_error.plot(style='k')
    
    
    error_peaks = smooth_error[smooth_error.cost >= peak_threshold]
    
    result = pandas.DataFrame({
                'start': pandas.Series([s for s,e,r in groundtruth]),
                'end':  pandas.Series([e for s,e,r in groundtruth]),
                'raw_reference': pandas.Series([1*any(r) for s,e,r in groundtruth]),
    })
    
    detection_gt = dict(zip(actions, np.zeros(len(actions))))
    detection_gt['false_alarm'] = 0

    detected = []
    for start, end, value in groundtruth:
        detected_value = len(error_peaks[(error_peaks.index > start) & (error_peaks.index < end)])
        detected.append(detected_value)
        
        for action in value:
            detection_gt[action] = int(detection_gt[action]) + 1
        else:
            detection_gt['false_alarm'] = detection_gt['false_alarm'] + 1
            
    detection_gt['total'] = 0
    for action in actions:
        detection_gt['total'] = detection_gt['total'] + detection_gt[action]

    detection = pandas.Series(detected, index=result.index)

    result['raw_detection'] = detection
    result['reference'] = [x==0 for x in result.raw_reference]
    result['detection'] = [x==0 for x in result.raw_detection]
    
    average_precision = average_precision_score(result.raw_reference, result.raw_detection)
    
    if plot:
        fes = check(data, groundtruth, error_limit=normal_data.error.quantile(0.992))
        
        data.error.plot(kind='line')
        smooth_error.plot(kind='line')
        error_peaks.plot(kind='line')
        
        
        precision, recall, th = precision_recall_curve(result.raw_reference, result.raw_detection)
        
        # Plot Precision-Recall curve
        plt.clf()
        plt.plot(recall, precision, label='Precision-Recall curve')
        plt.xlabel('Recall')
        plt.ylabel('Precision')
        plt.ylim([0.0, 1.05])
        plt.xlim([0.0, 1.0])
        plt.title('Precision-Recall example: AUC={0:0.2f}'.format(average_precision))
        plt.legend(loc="upper right")
        plt.show()

    return data, groundtruth, smooth_error, error_peaks, result, average_precision, detection_gt

# %%
SHORT_DATASETS = {
  "entrance": ('/home/x/traj/subway-entrance-W10-short.txt',
               '/home/x/traj/subway-entrance-ground-truth.csv',
               ["nopay", "loitering", "wrongdir","interaction", "etc"],
               entrance_detection,
               ),
  "exit":  ('/home/x/traj/subway-exit-W10-short.txt',
            '/home/x/traj/subway-exit-ground-truth.csv',
            ["nopay", "loitering", "wrongdir","interaction", "etc"],
            exit_detection,
           ),
}

LONG_DATASETS = {
  "entrance": ('/home/x/traj/subway-entrance-W10-long.txt',
               '/home/x/traj/subway-entrance-ground-truth.csv',
               ["nopay", "loitering", "wrongdir","interaction", "etc"],
               entrance_detection,
               ),
  "exit":  ('/home/x/traj/subway-exit-W10-long.txt',
            '/home/x/traj/subway-exit-ground-truth.csv',
            ["nopay", "loitering", "wrongdir","interaction", "etc"],
            exit_detection,
           ),
}

DATASETS = SHORT_DATASETS

# %%
for dataset, value in SHORT_DATASETS.iteritems():
    trajectory_file, groundtruth_file, actions, show_detection = value
    groundtruth = get_ground_truth(filename=groundtruth_file, actions=actions)
    # %time data, gt, smooth, error, result, performance, detection = unusual_events(trajectory_file=trajectory_file, groundtruth=groundtruth, actions=actions, plot=False)
    display(show_detection(detection, label='Ours '+dataset+ ' ' + 'lars'))

# %%
for dataset, value in LONG_DATASETS.iteritems():
    trajectory_file, groundtruth_file, actions, show_detection = value
    groundtruth = get_ground_truth(filename=groundtruth_file, actions=actions)
    # %time unusual_events(trajectory_file=trajectory_file, groundtruth=groundtruth, plot=False)
